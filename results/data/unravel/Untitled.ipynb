# %%
import pickle
objects_fur = []
with (open("breast_cancer_FUR_RBF_50.pickle", "rb")) as openfile:
    while True:
        try:
            objects_fur.append(pickle.load(openfile))
        except EOFError:
            break

# %%
objects_fur
# Out:
# [{'msd': [1.0510111299784815e-15,
#    9.565803215392067e-16,
#    9.677444031315948e-16,
#    0.2542255959025245,
#    0.33359614041811725,
#    1.0935696792557792e-15,
#    0.41751035462640984,
#    0.31989233711021625,
#    8.067620645609471e-16,
#    1.2064423534260035e-15],
#   'mis': [array([3.48037423, 1.47221584, 2.36249242, 1.07805988, 0.69692964,
#           0.3927715 , 1.59450257, 5.31969109, 0.62243806, 1.62162849,
#           0.86202389, 3.85228519, 2.15339068, 1.28632643, 2.98993537,
#           0.66144544, 0.5515384 , 1.14549301, 2.20706386, 2.51679826,
#           1.84053502, 1.92398349, 2.50650398, 0.92856421, 2.797423  ,
#           1.525588  , 0.58220027, 2.87453491, 1.44103978, 2.20522367]),
#    array([0.59707962, 0.83796438, 0.3808375 , 2.24759244, 0.71459599,
#           0.79833098, 1.48138043, 3.8884395 , 0.85836234, 1.22045947,
#           3.03552621, 0.91936448, 1.88641528, 2.62829531, 0.86783781,
# ...

# %%
objects_iffur = []
with (open("breast_cancer_IF_FUR_RBF_50.pickle", "rb")) as openfile:
    while True:
        try:
            objects_iffur.append(pickle.load(openfile))
        except EOFError:
            break

# %%
objects_iffur
# Out:
# [{'msd': [1.0510111299784815e-15,
#    1.195340123179752e-15,
#    1.195340123179752e-15,
#    1.195340123179752e-15,
#    1.195340123179752e-15,
#    1.195340123179752e-15,
#    1.195340123179752e-15,
#    1.195340123179752e-15,
#    1.195340123179752e-15,
#    1.195340123179752e-15],
#   'mis': [array([3.48037423, 1.47221584, 2.36249242, 1.07805988, 0.69692964,
#           0.3927715 , 1.59450257, 5.31969109, 0.62243806, 1.62162849,
#           0.86202389, 3.85228519, 2.15339068, 1.28632643, 2.98993537,
#           0.66144544, 0.5515384 , 1.14549301, 2.20706386, 2.51679826,
#           1.84053502, 1.92398349, 2.50650398, 0.92856421, 2.797423  ,
#           1.525588  , 0.58220027, 2.87453491, 1.44103978, 2.20522367]),
#    array([2.41287287, 1.14341001, 0.98947293, 6.53836892, 1.92331325,
#           0.90241536, 3.18436827, 6.25341178, 1.28991705, 1.42869987,
#           1.12037442, 1.74092249, 0.72799662, 8.47082445, 1.09405059,
# ...
